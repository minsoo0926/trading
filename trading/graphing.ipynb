# %%
from mine import trend_utils
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from utils import date_utils
import ccxt
import time

df1 = pd.read_csv('data/20200101-ETH_future.csv')
#df1=df1[:len(df1)-1]
binance = ccxt.binance()
eth = binance.fetch_ticker("ETH/USDT")

a = trend_utils.trend(df1[len(df1)-34:len(df1)].reset_index(drop=True))
print(a.near_trend(eth['close'], time.time()), eth['close'], a.f_max(time.time()), a.f_min(time.time()))
a.graph(df1)
# Out:
# sell 2922.68 2840.8334745378233 2809.1779546012403
